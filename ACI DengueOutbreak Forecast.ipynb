# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
df=pd.read_csv('DengueData.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Area  Month  Avg_Temperature_16  Avg_Temperature_17  \
# 0           0     2      4                  37                  37
# 1           1     9      3                  32                  31
# 2           2     8      6                  28                  19
# 3           3     3      3                  34                  33
# 4           4     5      2                  30                  31
#
#    Rainfall_16  Rainfall_17  Altitude  Avg_Humidity_16  Avg_Humidity_17  \
# 0         0.00          3.3     505.0               27               23
# 1         9.70          0.1     527.0               22               18
# 2       172.81        196.4    2600.0               54               74
# 3         0.80          0.0      81.0               23               21
# 4         0.00          0.0    1022.0               63               62
#
#    Dengue_Cases_16  Dengue_Cases_17
# 0               28               35
# 1               22               18
# ...

# %%
from sklearn.preprocessing import StandardScaler

NormalizedData=df

# %%
def Normalization(num):
    
    NormalizedData[df.columns[i]]=StandardScaler().fit_transform(df[df.columns[i]].values.reshape(-1,1))
    

for i in range(0,11):
    Normalization(i)
# Out:
# C:\Users\rohit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\rohit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\rohit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\rohit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
NormalizedData.head()
# Out:
#    Unnamed: 0      Area     Month  Avg_Temperature_16  Avg_Temperature_17  \
# 0   -1.731878 -1.204934 -0.950560            1.785687            1.825823
# 1   -1.731531  1.216279 -1.267488            0.736048            0.631980
# 2   -1.731185  0.870392 -0.316706           -0.103662           -1.755704
# 3   -1.730838 -0.859046 -1.267488            1.155904            1.029928
# 4   -1.730492 -0.167271 -1.584415            0.316193            0.631980
#
#    Rainfall_16  Rainfall_17  Altitude  Avg_Humidity_16  Avg_Humidity_17  \
# 0    -0.601896    -0.675847 -0.350864        -1.595292        -1.907904
# 1    -0.569035    -0.687302 -0.324303        -1.844257        -2.173290
# 2    -0.016471     0.015368  2.178461        -0.250882         0.799035
# 3    -0.599185    -0.687660 -0.862766        -1.794464        -2.014058
# 4    -0.601896    -0.687660  0.273318         0.197255         0.162108
#
#    Dengue_Cases_16  Dengue_Cases_17
# 0        -0.583789               35
# ...

# %%
sns.pairplot(df)

# %%
from sklearn.cross_validation import train_test_split

X=NormalizedData.drop('Dengue_Cases_17',axis=1)

y=NormalizedData['Dengue_Cases_17']

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

logmodel=LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
logmodel.score(x_test,y_test)
# Out:
# 0.9013333333333333

# %%
from sklearn.grid_search import GridSearchCV

param_grid={'C':[0.1,1,10,100,1000],'solver':['liblinear','newton-cg','lbfgs','sag','saga']}

grd=GridSearchCV(LogisticRegression(),param_grid,verbose=3)

grd.fit(x_train,y_train)
# Out:
# C:\Users\rohit\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, solver=liblinear .........................................
# [CV] ................ C=0.1, solver=liblinear, score=0.638099 -   1.4s
# [CV] C=0.1, solver=liblinear .........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV] ................ C=0.1, solver=liblinear, score=0.664809 -   1.6s
# [CV] C=0.1, solver=liblinear .........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [CV] ................ C=0.1, solver=liblinear, score=0.656277 -   1.4s
# ...

# %%
grd.score(x_test,y_test)
# Out:
# 0.9923333333333333

# %%
predictions=grd.predict(x_test)

# %%
alertregions=[]

for i in range(0,len(predictions)):
     
    if predictions[i]>=10:
        
        alertregions.append(x_test['Area'])

# %%
alertregions #These are the regions which are to be alerted.
# Out:
# [6676   -1.204934
#  6421   -1.204934
#  9834   -0.167271
#  8492    0.524504
#  9982    0.870392
#  8844   -0.167271
#  7247    0.524504
#  5862    0.524504
#  3662    1.216279
#  3457    1.216279
#  336     1.562167
#  6109   -0.167271
#  9784    0.524504
#  7769    0.870392
#  6971    0.870392
#  6001    0.178616
#  6995   -0.859046
#  9758   -1.204934
#  7115    0.178616
#  9925    1.216279
#  4421   -0.859046
#  4150    0.178616
#  5342   -1.550822
#  7122    0.178616
#  1185   -0.167271
#  3814   -0.167271
#  200    -0.513159
#  9812   -0.167271
#  8444   -1.204934
#  7925   -1.204934
#            ...
#  8570   -0.513159
#  1575    0.178616
#  4455    0.524504
#  6758   -0.859046
#  4092    1.562167
#  8292   -1.204934
#  7771    1.216279
#  7189   -1.550822
#  9522   -0.167271
#  1674    1.562167
#  82      1.216279
#  747     0.870392
#  5639   -0.167271
#  7777    1.562167
#  1525   -1.204934
#  3555   -1.204934
#  3267    0.178616
#  4969   -0.167271
#  9525    0.524504
# ...
