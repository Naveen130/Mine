# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



# %matplotlib inline

# %%
df=pd.read_csv('DengueData.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Area', 'Month', 'Avg_Temperature_16',
#        'Avg_Temperature_17', 'Rainfall_16', 'Rainfall_17', 'Altitude',
#        'Avg_Humidity_16', 'Avg_Humidity_17', 'Dengue_Cases_16',
#        'Dengue_Cases_17'],
#       dtype='object')

# %%
fig, ax = plt.subplots()

fig.set_size_inches(11.7, 8.27)


sns.barplot(x=df['Avg_Temperature_17'],y=df['Dengue_Cases_17'])

# %%
fig, ax = plt.subplots()

fig.set_size_inches(11.7, 8.27)


sns.barplot(x=df['Avg_Humidity_17'],y=df['Dengue_Cases_17'])

# %%
fig, ax = plt.subplots()

fig.set_size_inches(20, 8.27)



sns.barplot(x=df['Rainfall_17'].sample(n=500),y=df['Dengue_Cases_17'])

# %%
fig, ax = plt.subplots()

fig.set_size_inches(20, 8.27)


sns.barplot(x=df['Dengue_Cases_16'],y=df['Dengue_Cases_17'])

# %%
fig, ax = plt.subplots()

fig.set_size_inches(20, 8.27)

sns.barplot(x=df['Altitude'],y=df['Dengue_Cases_17'])
